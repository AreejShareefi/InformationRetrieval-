# %%
import requests 

from bs4 import BeautifulSoup as bs 

#request the page & present its html code

r = requests.get('https://www.timeout.com/film/the-best-films-of-2022-so-far') 



soup = bs(r.content) 


print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <title>
#    The 25 best films of 2022 (so far)
#   </title>
#   <meta content="The essential movies of the year: from ‘RRR’ to ‘Nope’" name="description"/>
#   <link href="https://www.timeout.com/film/the-best-films-of-2022-so-far" rel="canonical"/>
#   <script>
# ...

# %%
# using regular expression to print names of movies:- 

import re 

listOfMovies = soup.find_all('h3')

for tag in listOfMovies:
    movies=tag.contents[1]
    print(movies)
# Out:
#  Turning Red
#  Fire of Love
#  RRR
#  Cow
#  Boiling Point
#  Bergman Island
#  Jackass Forever
#  Prey
#  Wheel of Fortune and Fantasy
#  Elvis
#  A Hero
#  Belle
#  Benediction
#  The Woman King
#  Nope
#  All Quiet on the Western Front
#  Hit the Road
#  Brian and Charles
#  Everything Everywhere All at Once
#  Happening
#  The Worst Person in the World
#  Parallel Mothers
#  The Northman
#  Top Gun: Maverick
#  Licorice Pizza
