# %%
# !pip install python-terrier
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 97 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 33.7 MB/s
# ...
#      |████████████████████████████████| 69 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 303 kB 43.0 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 126 kB 52.8 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 72 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 44.0 MB/s
# ...
#      |████████████████████████████████| 294 kB 64.5 MB/s
# ...
#      |████████████████████████████████| 285 kB 59.7 MB/s
# ...

# %%
import pyterrier as pt
if not pt.started():
    pt.init()
# Out:
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.1 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %%
# !pip install stop-words
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32911 sha256=bdf33b6f4d52ee4d094f652586f4ca04c3e775fa82fd672179add565d4ce8ee4
#   Stored in directory: /root/.cache/pip/wheels/fb/86/b2/277b10b1ce9f73ce15059bf6975d4547cc4ec3feeb651978e9
# Successfully built stop-words
# ...

# %%
#we need to import the following libraries.

import pandas as pd

#to display the full text on the notebook without truncation

pd.set_option('display.max_colwidth', 150)

import re

from snowballstemmer import stemmer


from stop_words import get_stop_words
stp=get_stop_words('en')
 

#make your loops show a smart progress meter 

from tqdm import tqdm

# %%
#contents = file.read()
docs_df = pd.DataFrame([ 

                        ["d0", 'This is the second lab of the information retrieval cycle'],

                        ["d1", 'In this lab, we will learn how to deal with English texts'], 

                        ["d2",'Today is September 29, 2022. Accompanying is Thursday, Rabi` Al-Awwal 23, 1444' ], 

                        ["d3",'In this lab, you will learn about the methods of preparing data and trimming English texts' ]

                      ],

                        columns=["docID", "raw_text"])



docs_df
# Out:
#   docID  \
# 0    d0
# 1    d1
# 2    d2
# 3    d3
#
#                                                                                      raw_text
# 0                                   This is the second lab of the information retrieval cycle
# 1                                   In this lab, we will learn how to deal with English texts
# 2              Today is September 29, 2022. Accompanying is Thursday, Rabi` Al-Awwal 23, 1444
# 3  In this lab, you will learn about the methods of preparing data and trimming English texts

# %%
stp
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  "can't",
#  'cannot',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  "let's",
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
# ...

# %%
len(stp)
# Out:
# 174

# %%
#removing Stop Words function

def remove_stopWords(sentence):

    terms=[]

    stopWords= set(stp)

    for term in sentence.split() : 

        if term not in stopWords :

           terms.append(term)

    return " ".join(terms)



docs_df["Removed_Stop_word_text"]=docs_df["raw_text"].apply(remove_stopWords)

print("***************************************************************************documents after removing stopwords*********************************************************************")
docs_df
# Out:
# ***************************************************************************documents after removing stopwords*********************************************************************
#   docID  \
# 0    d0
# 1    d1
# 2    d2
# 3    d3
#
#                                                                                      raw_text  \
# 0                                   This is the second lab of the information retrieval cycle
# 1                                   In this lab, we will learn how to deal with English texts
# 2              Today is September 29, 2022. Accompanying is Thursday, Rabi` Al-Awwal 23, 1444
# 3  In this lab, you will learn about the methods of preparing data and trimming English texts
#
#                                                      Removed_Stop_word_text
# 0                               This second lab information retrieval cycle
# 1                                     In lab, will learn deal English texts
# ...

# %%
#a function to normalize the tweets

def normalize(text):

    text = text.lower()
    text = re.sub("[.,'-_?;:!()]", "", text)
    text = re.sub("sses", "ss", text)
    text = re.sub("y", "i", text)
    text = re.sub("ies", "i", text)
    text = re.sub("tional", "tion", text)
    text = re.sub("(m>1)ement", "", text)
    return(text)



docs_df["normalized_text"]=docs_df["Removed_Stop_word_text"].apply(normalize)

print("***************************************************************************documents after normalizing*********************************************************************")

docs_df
# Out:
# ***************************************************************************documents after normalizing*********************************************************************
#   docID  \
# 0    d0
# 1    d1
# 2    d2
# 3    d3
#
#                                                                                      raw_text  \
# 0                                   This is the second lab of the information retrieval cycle
# 1                                   In this lab, we will learn how to deal with English texts
# 2              Today is September 29, 2022. Accompanying is Thursday, Rabi` Al-Awwal 23, 1444
# 3  In this lab, you will learn about the methods of preparing data and trimming English texts
#
#                                                      Removed_Stop_word_text  \
# 0                               This second lab information retrieval cycle
# 1                                     In lab, will learn deal English texts
# ...

# %%
#specify that we want to stem arabic text

en_stemmer = stemmer("english")

#define the stemming function

def stem(sentence):

    return " ".join([en_stemmer.stemWord(i) for i in sentence.split()])



docs_df['Stemtext']=docs_df['normalized_text'].apply(stem)

print("***************************************************************************documents after stemming*********************************************************************")

docs_df
# Out:
# ***************************************************************************documents after stemming*********************************************************************
#   docID  \
# 0    d0
# 1    d1
# 2    d2
# 3    d3
#
#                                                                                      raw_text  \
# 0                                   This is the second lab of the information retrieval cycle
# 1                                   In this lab, we will learn how to deal with English texts
# 2              Today is September 29, 2022. Accompanying is Thursday, Rabi` Al-Awwal 23, 1444
# 3  In this lab, you will learn about the methods of preparing data and trimming English texts
#
#                                                      Removed_Stop_word_text  \
# 0                               This second lab information retrieval cycle
# 1                                     In lab, will learn deal English texts
# ...
